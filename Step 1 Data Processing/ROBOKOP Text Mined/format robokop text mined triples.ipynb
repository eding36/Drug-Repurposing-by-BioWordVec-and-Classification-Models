# %%
import os
import pandas as pd 
import json

print(os.getcwd())

df_raw = pd.read_csv(os.path.join(os.getcwd(),'Raw Data/ROBOKOP Drug-Gene-Target Triples Virtual Step 4 Screening Set.csv'))
# Out:
# /Users/eding/PycharmProjects/U24-ROBOKOP-Project-8-15-24/Data Processing/ROBOKOP Text Mined

# %%
#####import hgnc complete set to change gene names that can be changed to protein names

json_file = os.path.join(os.path.dirname(os.getcwd()), 'ROBOKOP+DrugmechDB/hgnc_complete_set.json')
with open(json_file, 'r') as file:
    data = json.load(file)

data_len = len(data['response']['docs'])

gene_prot_list = []

for i in range(data_len):
    try:
        gene_symbol = data['response']['docs'][i]['symbol']
        protein_name = data['response']['docs'][i]['name']
        protein_id = data['response']['docs'][i]['uniprot_ids'][0]
        row = [gene_symbol,protein_name,protein_id]
        gene_prot_list.append(row)
    except KeyError:
        gene_symbol = data['response']['docs'][i]['symbol']
        protein_name = data['response']['docs'][i]['name']
        protein_id = 'null'
        row = [gene_symbol,protein_name,protein_id]
        gene_prot_list.append(row)

columns = ['symbol','name','uniprot id']

hgnc_df = pd.DataFrame(gene_prot_list, columns=columns)

# %%
print(hgnc_df)
# Out:
#          symbol                                               name uniprot id
# 0          A1BG                             alpha-1-B glycoprotein     P04217
# 1      A1BG-AS1                               A1BG antisense RNA 1       null
# 2          A1CF                     APOBEC1 complementation factor     Q9NQ94
# 3           A2M                              alpha-2-macroglobulin     P01023
# 4       A2M-AS1                                A2M antisense RNA 1       null
# ...         ...                                                ...        ...
# 43846    ZYG11B       zyg-11 family member B, cell cycle regulator     Q9C0D3
# 43847       ZYX                                              zyxin     Q15942
# 43848     ZYXP1                                 zyxin pseudogene 1       null
# 43849     ZZEF1  zinc finger ZZ-type and EF-hand domain contain...     O43149
# 43850      ZZZ3                   zinc finger ZZ-type containing 3     Q8IYH5
#
# [43851 rows x 3 columns]

# %%
print(df_raw)
# Out:
#                                                   c.name          c.id  \
# 0                                             vandetanib   CHEBI:49960
# 1                                              ponatinib   CHEBI:78543
# 2                                              sorafenib   CHEBI:50924
# 3                                            regorafenib   CHEBI:68647
# 4                                            ruxolitinib   CHEBI:66919
# ...                                                  ...           ...
# 99995                                          LY3009120  CHEBI:167662
# 99996                                          CH5126766   CHEBI:78825
# 99997                                           GDC-0879   CHEBI:83405
# 99998  N-(5-{[(5-tert-butyl-1,3-oxazol-2-yl)methyl]su...   CHEBI:91399
# 99999                                           PLX-4720   CHEBI:90295
#
#                                                       r0 g.name  \
# 0      {"agent_type":not_provided,"knowledge_level":n...    RET
# 1      {"agent_type":not_provided,"knowledge_level":n...    RET
# 2      {"agent_type":not_provided,"knowledge_level":n...    RET
# 3      {"agent_type":not_provided,"knowledge_level":n...    RET
# 4      {"agent_type":not_provided,"knowledge_level":n...    RET
# ...                                                  ...    ...
# 99995  {"agent_type":manual_agent,"knowledge_level":k...   BRAF
# 99996  {"agent_type":not_provided,"knowledge_level":n...   BRAF
# 99997  {"agent_type":manual_agent,"knowledge_level":k...   BRAF
# 99998  {"agent_type":manual_agent,"knowledge_level":k...   BRAF
# 99999  {"agent_type":not_provided,"knowledge_level":n...   BRAF
#
#                 g.id                                                 r1  \
# 0      NCBIGene:5979  {"agent_type":not_provided,"knowledge_level":n...
# 1      NCBIGene:5979  {"agent_type":not_provided,"knowledge_level":n...
# 2      NCBIGene:5979  {"agent_type":not_provided,"knowledge_level":n...
# 3      NCBIGene:5979  {"agent_type":not_provided,"knowledge_level":n...
# 4      NCBIGene:5979  {"agent_type":not_provided,"knowledge_level":n...
# ...              ...                                                ...
# 99995   NCBIGene:673  {"agent_type":not_provided,"knowledge_level":n...
# 99996   NCBIGene:673  {"agent_type":not_provided,"knowledge_level":n...
# 99997   NCBIGene:673  {"agent_type":not_provided,"knowledge_level":n...
# 99998   NCBIGene:673  {"agent_type":not_provided,"knowledge_level":n...
# 99999   NCBIGene:673  {"agent_type":not_provided,"knowledge_level":n...
#
#                                      d.name           d.id
# 0      multiple endocrine neoplasia type 2A   DOID:0050430
# 1      multiple endocrine neoplasia type 2A   DOID:0050430
# 2      multiple endocrine neoplasia type 2A   DOID:0050430
# 3      multiple endocrine neoplasia type 2A   DOID:0050430
# 4      multiple endocrine neoplasia type 2A   DOID:0050430
# ...                                     ...            ...
# 99995                          liver cancer  MONDO:0002691
# 99996                          liver cancer  MONDO:0002691
# 99997                          liver cancer  MONDO:0002691
# 99998                          liver cancer  MONDO:0002691
# 99999                          liver cancer  MONDO:0002691
#
# [100000 rows x 8 columns]

# %%
columns = ['c.name','c.id','d.name','d.id', 'g.name','g.id']
df = df_raw[columns]
df.columns = ['drug_name', 'drug.id','disease_name', 'disease.id','gene_name','gene.id']

# %%
print(df)
# Out:
#                                                drug_name       drug.id  \
# 0                                             vandetanib   CHEBI:49960
# 1                                              ponatinib   CHEBI:78543
# 2                                              sorafenib   CHEBI:50924
# 3                                            regorafenib   CHEBI:68647
# 4                                            ruxolitinib   CHEBI:66919
# ...                                                  ...           ...
# 99995                                          LY3009120  CHEBI:167662
# 99996                                          CH5126766   CHEBI:78825
# 99997                                           GDC-0879   CHEBI:83405
# 99998  N-(5-{[(5-tert-butyl-1,3-oxazol-2-yl)methyl]su...   CHEBI:91399
# 99999                                           PLX-4720   CHEBI:90295
#
#                                disease_name     disease.id gene_name  \
# 0      multiple endocrine neoplasia type 2A   DOID:0050430       RET
# 1      multiple endocrine neoplasia type 2A   DOID:0050430       RET
# 2      multiple endocrine neoplasia type 2A   DOID:0050430       RET
# 3      multiple endocrine neoplasia type 2A   DOID:0050430       RET
# 4      multiple endocrine neoplasia type 2A   DOID:0050430       RET
# ...                                     ...            ...       ...
# 99995                          liver cancer  MONDO:0002691      BRAF
# 99996                          liver cancer  MONDO:0002691      BRAF
# 99997                          liver cancer  MONDO:0002691      BRAF
# 99998                          liver cancer  MONDO:0002691      BRAF
# 99999                          liver cancer  MONDO:0002691      BRAF
#
#              gene.id
# 0      NCBIGene:5979
# 1      NCBIGene:5979
# 2      NCBIGene:5979
# 3      NCBIGene:5979
# 4      NCBIGene:5979
# ...              ...
# 99995   NCBIGene:673
# 99996   NCBIGene:673
# 99997   NCBIGene:673
# 99998   NCBIGene:673
# 99999   NCBIGene:673
#
# [100000 rows x 6 columns]

# %%
for i in range(len(df)):
    df.iloc[i,0] = df.iloc[i,0].lower()
    df.iloc[i,2] = df.iloc[i,2].lower()
    df.iloc[i,4] = df.iloc[i,4].lower()

df['gene_name'] = df['gene_name'].replace('pgk 1.00', 'pgk1').replace('npr 2.00', 'npr2').replace('top 1.00', 'top1').replace('cyp 20.00', 'cyp20')
# Out:
# /var/folders/91/rbzkmg7n5g7f992d83ryjnz40000gn/T/ipykernel_79056/3305338610.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[i,0] = df.iloc[i,0].lower()
# /var/folders/91/rbzkmg7n5g7f992d83ryjnz40000gn/T/ipykernel_79056/3305338610.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[i,2] = df.iloc[i,2].lower()
# /var/folders/91/rbzkmg7n5g7f992d83ryjnz40000gn/T/ipykernel_79056/3305338610.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[i,4] = df.iloc[i,4].lower()
# /var/folders/91/rbzkmg7n5g7f992d83ryjnz40000gn/T/ipykernel_79056/3305338610.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gene_name'] = df['gene_name'].replace('pgk 1.00', 'pgk1').replace('npr 2.00', 'npr2').replace('top 1.00', 'top1').replace('cyp 20.00', 'cyp20')

# %%
print(df)
# Out:
#                                                drug_name       drug.id  \
# 0                                             vandetanib   CHEBI:49960
# 1                                              ponatinib   CHEBI:78543
# 2                                              sorafenib   CHEBI:50924
# 3                                            regorafenib   CHEBI:68647
# 4                                            ruxolitinib   CHEBI:66919
# ...                                                  ...           ...
# 99995                                          ly3009120  CHEBI:167662
# 99996                                          ch5126766   CHEBI:78825
# 99997                                           gdc-0879   CHEBI:83405
# 99998  n-(5-{[(5-tert-butyl-1,3-oxazol-2-yl)methyl]su...   CHEBI:91399
# 99999                                           plx-4720   CHEBI:90295
#
#                                disease_name     disease.id gene_name  \
# 0      multiple endocrine neoplasia type 2a   DOID:0050430       ret
# 1      multiple endocrine neoplasia type 2a   DOID:0050430       ret
# 2      multiple endocrine neoplasia type 2a   DOID:0050430       ret
# 3      multiple endocrine neoplasia type 2a   DOID:0050430       ret
# 4      multiple endocrine neoplasia type 2a   DOID:0050430       ret
# ...                                     ...            ...       ...
# 99995                          liver cancer  MONDO:0002691      braf
# 99996                          liver cancer  MONDO:0002691      braf
# 99997                          liver cancer  MONDO:0002691      braf
# 99998                          liver cancer  MONDO:0002691      braf
# 99999                          liver cancer  MONDO:0002691      braf
#
#              gene.id
# 0      NCBIGene:5979
# 1      NCBIGene:5979
# 2      NCBIGene:5979
# 3      NCBIGene:5979
# 4      NCBIGene:5979
# ...              ...
# 99995   NCBIGene:673
# 99996   NCBIGene:673
# 99997   NCBIGene:673
# 99998   NCBIGene:673
# 99999   NCBIGene:673
#
# [100000 rows x 6 columns]

# %%
#####TO OBTAIN DATASET WITH ONLY PROTEIN DESCRIPTORS (IF YOU ONLY WANT GENE NAMES SKIP THIS STEP)######

def GetProteinName(gene_name):
    try:
        i = hgnc_df[hgnc_df['symbol']==gene_name.upper()].index.values
        #print(str(i) + " is the index")
        index = int(i[0])
        protein = hgnc_df.at[index, 'name']
        protein_id = hgnc_df.at[index, 'uniprot id']
        #print(gene + " maps to " + protein)
    except:
        print(f"Could not map gene symbol:{gene_name}")
        protein = 'null'
        protein_id = 'null'
    return protein, protein_id

for i in range(len(df)):
    protein_descriptor, protein_id = GetProteinName(df.iloc[i,4])
    df.iloc[i,4] = protein_descriptor.lower()
    df.iloc[i,5] = protein_id

filtered_df = df[(df['gene_name'] != "null") & (df['gene.id'] != "null")]  ###remove all rows where gene couldnt be converted to protein name
filtered_df.rename(columns ={'gene_name':'protein_name', 'gene.id':'protein_id'},inplace = True)
filtered_df.to_csv(os.path.join(os.getcwd(), 'Processed Data/ROBOKOP Text Mined Triples.csv')
)
# Out:
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:cyp20
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd6
# Could not map gene symbol:nd2
# Could not map gene symbol:nd3
# Could not map gene symbol:nd5
# Could not map gene symbol:nd4l
# Could not map gene symbol:nd4
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd4
# Could not map gene symbol:nd5
# Could not map gene symbol:nd6
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd2
# Could not map gene symbol:nd3
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:erg11
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd4
# Could not map gene symbol:nd6
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd5
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:nd1
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# Could not map gene symbol:cyp 20.00
# /var/folders/91/rbzkmg7n5g7f992d83ryjnz40000gn/T/ipykernel_90116/1242341842.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.rename(columns ={'gene_name':'protein_name', 'gene.id':'protein_id'},inplace = True)

# %%
from libchebipy._chebi_entity import ChebiEntity
entity = ChebiEntity('49960')
print(entity)
smiles = entity.get_smiles()
print(smiles)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:1573, in FTPHandler.ftp_open(self, req)
#    1572         type = value.upper()
# -> 1573 fp, retrlen = fw.retrfile(file, type)
#    1574 headers = ""
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:2448, in ftpwrapper.retrfile(self, file, type)
#    2447     cmd = 'RETR ' + file
# -> 2448     conn, retrlen = self.ftp.ntransfercmd(cmd)
#    2449 except ftplib.error_perm as reason:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ftplib.py:354, in FTP.ntransfercmd(self, cmd, rest)
#     353 host, port = self.makepasv()
# --> 354 conn = socket.create_connection((host, port), self.timeout,
#     355                                 source_address=self.source_address)
#     356 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:852, in create_connection(address, timeout, source_address, all_errors)
#     851 if not all_errors:
# --> 852     raise exceptions[0]
#     853 raise ExceptionGroup("create_connection failed", exceptions)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:837, in create_connection(address, timeout, source_address, all_errors)
#     836     sock.bind(source_address)
# --> 837 sock.connect(sa)
#     838 # Break explicitly a reference cycle
#
# TimeoutError: [Errno 60] Operation timed out
#
# The above exception was the direct cause of the following exception:
#
# URLError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 from libchebipy._chebi_entity import ChebiEntity
# ----> 2 entity = ChebiEntity('49960')
#       3 print(entity)
#       4 smiles = entity.get_smiles()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/libchebipy/_chebi_entity.py:30, in ChebiEntity.__init__(self, chebi_id)
#      27 self.__chebi_id = int(chebi_id.replace('CHEBI:', ''))
#      28 self.__all_ids = None
# ---> 30 if self.get_name() is None:
#      31     raise ChebiException('ChEBI id ' + chebi_id + ' invalid')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/libchebipy/_chebi_entity.py:93, in ChebiEntity.get_name(self)
#      91 def get_name(self):
#      92     '''Returns name'''
# ---> 93     name = parsers.get_name(self.__chebi_id)
#      95     if name is None:
#      96         name = parsers.get_name(self.get_parent_id())
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/libchebipy/_parsers.py:242, in get_name(chebi_id)
#     240 '''Returns name'''
#     241 if not __NAMES:
# --> 242     __parse_compounds()
#     244 return __NAMES[chebi_id] if chebi_id in __NAMES else None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/libchebipy/_parsers.py:289, in __parse_compounds()
#     287 def __parse_compounds():
#     288     '''Gets and parses file'''
# --> 289     filename = get_file('compounds.tsv.gz')
#     291     with io.open(filename, 'r', encoding='cp1252') as textfile:
#     292         next(textfile)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/libchebipy/_parsers.py:617, in get_file(filename)
#     613         os.makedirs(destination)
#     615     url = 'ftp://ftp.ebi.ac.uk/pub/databases/chebi/' + \
#     616         'Flat_file_tab_delimited/'
# --> 617     urlretrieve(urlparse.urljoin(url, filename), filepath)
#     618     urlcleanup()
#     620 if filepath.endswith('.zip'):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:240, in urlretrieve(url, filename, reporthook, data)
#     223 """
#     224 Retrieve a URL into a temporary location on disk.
#     225
#    (...)
#     236 data file as well as the resulting HTTPMessage object.
#     237 """
#     238 url_type, path = _splittype(url)
# --> 240 with contextlib.closing(urlopen(url, data)) as fp:
#     241     headers = fp.info()
#     243     # Just return the local path and the "headers" for file://
#     244     # URLs. No sense in performing a copy unless requested.
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:1583, in FTPHandler.ftp_open(self, req)
#    1581     return addinfourl(fp, headers, req.full_url)
#    1582 except ftplib.all_errors as exp:
# -> 1583     raise URLError(exp) from exp
#
# URLError: <urlopen error [Errno 60] Operation timed out>
