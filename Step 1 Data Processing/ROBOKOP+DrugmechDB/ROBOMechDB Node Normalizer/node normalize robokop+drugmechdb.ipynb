# %%
import pandas as pd
import requests as rq
import os
parent_dir =os.path.dirname(os.getcwd()) 

drugmech_array = pd.read_csv(os.path.join(parent_dir,'DrugmechDB Data/Processed Data/DrugMechDB Processed Triples.csv'))

robokops_array = pd.read_csv(os.path.join(parent_dir,'ROBOKOP Data/ROBOKOP Processed Triples.csv'))

# %%
stacked_df = pd.concat([drugmech_array, robokops_array], axis=0,ignore_index=True)
stacked_df = stacked_df.drop('Unnamed: 0', axis = 1)

# %%
print(stacked_df)
# Out:
#            drug_name           drug_id  \
# 0           imatinib  DRUGBANK:DB00619
# 1           imatinib  DRUGBANK:DB00619
# 2           imatinib  DRUGBANK:DB00619
# 3      acetaminophen  DRUGBANK:DB00316
# 4      acetaminophen  DRUGBANK:DB00316
# ...              ...               ...
# 11940   theophylline       CHEBI:28177
# 11941     dyphylline        CHEBI:4728
# 11942     dyphylline        CHEBI:4728
# 11943     dyphylline        CHEBI:4728
# 11944     dyphylline        CHEBI:4728
#
#                                             disease_name     disease_id  \
# 0                                              cml (ph+)   MESH:D015464
# 1                             systemic mast cell disease   MESH:D034721
# 2                             systemic mast cell disease   MESH:D034721
# 3                                                   pain   MESH:D010146
# 4                                                   pain   MESH:D010146
# ...                                                  ...            ...
# 11940  asthma-chronic obstructive pulmonary disease o...  UMLS:C4038730
# 11941  asthma-chronic obstructive pulmonary disease o...  UMLS:C4038730
# 11942  asthma-chronic obstructive pulmonary disease o...  UMLS:C4038730
# 11943  asthma-chronic obstructive pulmonary disease o...  UMLS:C4038730
# 11944  asthma-chronic obstructive pulmonary disease o...  UMLS:C4038730
#
#       gene_name           gene_id
# 0           NaN  UniProtKB:P00519
# 1           NaN  UniProtKB:P10721
# 2           NaN  UniProtKB:P16234
# 3           NaN  UniProtKB:P23219
# 4           NaN  UniProtKB:P35354
# ...         ...               ...
# 11940     pde4b     NCBIGene:5142
# 11941     pde4d     NCBIGene:5144
# 11942     pde4c     NCBIGene:5143
# 11943     pde4a     NCBIGene:5141
# 11944     pde4b     NCBIGene:5142
#
# [11945 rows x 6 columns]

# %%
import json
import time 

def run_node_normalizer(id):
    id_url = id.replace(":","%3A")
    URL= f"https://nodenormalization-sri.renci.org/1.5/get_normalized_nodes?curie={id_url}&conflate=true&drug_chemical_conflate=true&description=false"
    response = rq.get(url = URL)
    response_json = response.json()
    if response.status_code == 200 and response_json[id] != None:
        identifier = response_json[id]["id"]["identifier"]
        name = response_json[id]["id"]["label"].lower()
    return identifier, name

# %%
drug_dict = {}

for index, row in stacked_df.iterrows():
    try:
        print(f"Iteration: {index}")
        if row['drug_id'] in drug_dict.keys():
            stacked_df.loc[index,'drug_name'] = drug_dict[row['drug_id']][1]
            stacked_df.loc[index,'drug_id'] = drug_dict[row['drug_id']][0]
        else: 
            id, name = run_node_normalizer(row['drug_id']) 
            drug_dict.update({row['drug_id']:[id, name]})
            stacked_df.loc[index,'drug_name'] = drug_dict[row['drug_id']][1]
            stacked_df.loc[index,'drug_id'] = drug_dict[row['drug_id']][0]
    except UnboundLocalError: ###if the triple can't be node normalized, remove this row
        stacked_df.loc[index,'drug_name'] = 0
        print(f"Skipped {index} bc node normalizer cant find this")
        continue
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Skipped 12 bc node normalizer cant find this
# Iteration: 13
# Skipped 13 bc node normalizer cant find this
# Iteration: 14
# Skipped 14 bc node normalizer cant find this
# Iteration: 15
# Skipped 15 bc node normalizer cant find this
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27
# Iteration: 28
# Iteration: 29
# Iteration: 30
# Iteration: 31
# Iteration: 32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       8     stacked_df.loc[index,'drug_id'] = drug_dict[row['drug_id']][0]
#       9 else:
# ---> 10     id, name = run_node_normalizer(row['drug_id'])
#      11     drug_dict.update({row['drug_id']:[id, name]})
#      12     stacked_df.loc[index,'drug_name'] = drug_dict[row['drug_id']][1]
#
# Cell In[7], line 7, in run_node_normalizer(id)
#       5 id_url = id.replace(":","%3A")
#       6 URL= f"https://nodenormalization-sri.renci.org/1.5/get_normalized_nodes?curie={id_url}&conflate=true&drug_chemical_conflate=true&description=false"
# ----> 7 response = rq.get(url = URL)
#       8 response_json = response.json()
#       9 if response.status_code == 200 and response_json[id] != None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/adapters.py:564, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     563 try:
# --> 564     resp = conn.urlopen(
#     565         method=request.method,
#     566         url=url,
#     567         body=request.body,
#     568         headers=request.headers,
#     569         redirect=False,
#     570         assert_same_host=False,
#     571         preload_content=False,
#     572         decode_content=False,
#     573         retries=self.max_retries,
#     574         timeout=timeout,
#     575         chunked=chunked,
#     576     )
#     578 except (ProtocolError, OSError) as err:
#     579     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1097 # Force connect early to allow us to validate the connection.
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1102 if not conn.is_verified and not conn.proxy_is_verified:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:653, in HTTPSConnection.connect(self)
#     650 # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     651 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 653 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     654     sock=sock,
#     655     cert_reqs=self.cert_reqs,
#     656     ssl_version=self.ssl_version,
#     657     ssl_minimum_version=self.ssl_minimum_version,
#     658     ssl_maximum_version=self.ssl_maximum_version,
#     659     ca_certs=self.ca_certs,
#     660     ca_cert_dir=self.ca_cert_dir,
#     661     ca_cert_data=self.ca_cert_data,
#     662     cert_file=self.cert_file,
#     663     key_file=self.key_file,
#     664     key_password=self.key_password,
#     665     server_hostname=server_hostname_rm_dot,
#     666     ssl_context=self.ssl_context,
#     667     tls_in_tls=tls_in_tls,
#     668     assert_hostname=self.assert_hostname,
#     669     assert_fingerprint=self.assert_fingerprint,
#     670 )
#     671 self.sock = sock_and_verified.socket
#     673 # Forwarding proxies can never have a verified target since
#     674 # the proxy is the one doing the verification. Should instead
#     675 # use a CONNECT tunnel in order to verify the target.
#     676 # See: https://github.com/urllib3/urllib3/issues/3267.
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:806, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     803     if is_ipaddress(normalized):
#     804         server_hostname = normalized
# --> 806 ssl_sock = ssl_wrap_socket(
#     807     sock=sock,
#     808     keyfile=key_file,
#     809     certfile=cert_file,
#     810     key_password=key_password,
#     811     ca_certs=ca_certs,
#     812     ca_cert_dir=ca_cert_dir,
#     813     ca_cert_data=ca_cert_data,
#     814     server_hostname=server_hostname,
#     815     ssl_context=context,
#     816     tls_in_tls=tls_in_tls,
#     817 )
#     819 try:
#     820     if assert_fingerprint:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:465, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     462 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     463     pass
# --> 465 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     466 return ssl_sock
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:509, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     506     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     507     return SSLTransport(sock, ssl_context, server_hostname)
# --> 509 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             if timeout == 0.0:
#    1040                 # non-blocking
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#    1044     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1318     if timeout == 0.0 and block:
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#    1322     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
disease_dict = {}

for index, row in stacked_df.iterrows():
    try:
        print(f"Iteration: {index}")
        if row['disease_id'] in disease_dict.keys():
            stacked_df.loc[index,'disease_name'] = disease_dict[row['disease_id']][1]
            stacked_df.loc[index,'disease_id'] = disease_dict[row['disease_id']][0]
        else: 
            id, name = run_node_normalizer(row['disease_id'])
            disease_dict.update({row['disease_id']:[id, name]})
            stacked_df.loc[index,'disease_name'] = disease_dict[row['disease_id']][1]
            stacked_df.loc[index,'disease_id'] = disease_dict[row['disease_id']][0]
    except UnboundLocalError:
        stacked_df.loc[index,'disease_name'] = 0
        print(f"Skipped {index} bc node normalizer cant find this")
        continue

# %%
gene_dict = {}

for index, row in stacked_df.iterrows():
    try:
        print(f"Iteration: {index}")
        if row['gene_id'] in gene_dict.keys():
            stacked_df.loc[index,'gene_name'] = gene_dict[row['gene_id']][1]
            stacked_df.loc[index,'gene_id'] = gene_dict[row['gene_id']][0]
        else: 
            id, name = run_node_normalizer(row['gene_id']) 
            gene_dict.update({row['gene_id']:[id, name]})
            stacked_df.loc[index,'gene_name'] = gene_dict[row['gene_id']][1]
            stacked_df.loc[index,'gene_id'] = gene_dict[row['gene_id']][0]
    except UnboundLocalError:
        stacked_df.loc[index,'gene_name'] = 0
        print(f"Skipped {index} bc node normalizer cant find this")
        continue

# %%
#####data cleaning ###remove all nodes that can't be node normalized
columns_to_check = ['drug_name','disease_name','gene_name']
stacked_df = stacked_df[~(stacked_df[columns_to_check] == 0).any(axis=1)]

# %%
#####import hgnc complete set to change gene names that can be changed to protein names
json_file = os.path.join(parent_dir, 'hgnc_complete_set.json')
with open(json_file, 'r') as file:
    data = json.load(file)

data_len = len(data['response']['docs'])

gene_prot_list = []

for i in range(data_len):
    gene_symbol = data['response']['docs'][i]['symbol']
    protein_name = data['response']['docs'][i]['name']
    row = [gene_symbol,protein_name]
    gene_prot_list.append(row)

columns = ['symbol','name']

hgnc_df = pd.DataFrame(gene_prot_list, columns=['symbol','name'])

# %%
print(stacked_df)
# Out:
#           drug_name      drug_id  \
# 0          imatinib  CHEBI:45783
# 1          imatinib  CHEBI:45783
# 2          imatinib  CHEBI:45783
# 3       paracetamol  CHEBI:46195
# 4       paracetamol  CHEBI:46195
# ...             ...          ...
# 11940  theophylline  CHEBI:28177
# 11941    dyphylline   CHEBI:4728
# 11942    dyphylline   CHEBI:4728
# 11943    dyphylline   CHEBI:4728
# 11944    dyphylline   CHEBI:4728
#
#                                             disease_name     disease_id  \
# 0                                              cml (ph+)   MESH:D015464
# 1                             systemic mast cell disease   MESH:D034721
# 2                             systemic mast cell disease   MESH:D034721
# 3                                                   pain   MESH:D010146
# 4                                                   pain   MESH:D010146
# ...                                                  ...            ...
# 11940  asthma-chronic obstructive pulmonary disease o...  UMLS:C4038730
# 11941  asthma-chronic obstructive pulmonary disease o...  UMLS:C4038730
# 11942  asthma-chronic obstructive pulmonary disease o...  UMLS:C4038730
# 11943  asthma-chronic obstructive pulmonary disease o...  UMLS:C4038730
# 11944  asthma-chronic obstructive pulmonary disease o...  UMLS:C4038730
#
#       gene_name           gene_id
# 0           NaN  UniProtKB:P00519
# 1           NaN  UniProtKB:P10721
# 2           NaN  UniProtKB:P16234
# 3           NaN  UniProtKB:P23219
# 4           NaN  UniProtKB:P35354
# ...         ...               ...
# 11940     pde4b     NCBIGene:5142
# 11941     pde4d     NCBIGene:5144
# 11942     pde4c     NCBIGene:5143
# 11943     pde4a     NCBIGene:5141
# 11944     pde4b     NCBIGene:5142
#
# [11945 rows x 6 columns]

# %%
#####TO OBTAIN DATASET WITH ONLY PROTEIN DESCRIPTORS (IF YOU ONLY WANT GENE NAMES SKIP THIS STEP)######
import pandas as pd

def GetProteinName(gene_name):
    try:
        i = hgnc_df[hgnc_df['symbol']==gene_name.upper()].index.values
        #print(str(i) + " is the index")
        index = int(i[0])
        protein = hgnc_df.at[index, 'name']
        #print(gene + " maps to " + protein)
    except:
        print(f"Could not map gene symbol:{gene_name}")
        protein = 'null'
    return protein

for i in range(len(stacked_df)):
    protein_descriptor = GetProteinName(stacked_df.iloc[i,4]).lower()
    stacked_df.iloc[i,4] = protein_descriptor
# Out:
# Could not map gene symbol:parc_haein dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:rs12_ecoli small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:erg11
# Could not map gene symbol:pbp2_strr6 penicillin-binding protein 2b (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:rl10_haein large ribosomal subunit protein ul10 (sprot)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:mrda_ecoli peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:mrda_haein peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:rl10_salti large ribosomal subunit protein ul10 (sprot)
# Could not map gene symbol:dpol_hcmva dna polymerase catalytic subunit (sprot)
# Could not map gene symbol:rpoc
# Could not map gene symbol:dacb_ecoli d-alanyl-d-alanine carboxypeptidase dacb (sprot)
# Could not map gene symbol:pbpa_strr6 penicillin-binding protein 1a (sprot)
# Could not map gene symbol:ccd84_rs00625
# Could not map gene symbol:dacb_ecoli d-alanyl-d-alanine carboxypeptidase dacb (sprot)
# Could not map gene symbol:ccd84_rs00625
# Could not map gene symbol:pbpx_strr6 penicillin-binding protein 2x (sprot)
# Could not map gene symbol:pbp2_strr6 penicillin-binding protein 2b (sprot)
# Could not map gene symbol:pbpa_strr6 penicillin-binding protein 1a (sprot)
# Could not map gene symbol:pbp2_strr6 penicillin-binding protein 2b (sprot)
# Could not map gene symbol:pbpa_strr6 penicillin-binding protein 1a (sprot)
# Could not map gene symbol:an06g01550
# Could not map gene symbol:q72874_9hiv1 pol polyprotein (fragment) (trembl)
# Could not map gene symbol:folp
# Could not map gene symbol:dhps1_mycle dihydropteroate synthase (sprot)
# Could not map gene symbol:a0a0f4er22_9myco dihydropteroate synthase (trembl)
# Could not map gene symbol:que80_rs28345
# Could not map gene symbol:bla1_ecolx beta-lactamase shv-1 (sprot)
# Could not map gene symbol:bla1_ecolx beta-lactamase shv-1 (sprot)
# Could not map gene symbol:b0b3c9_9hepc genome polyprotein (fragment) (trembl)
# Could not map gene symbol:b0b3c9_9hepc genome polyprotein (fragment) (trembl)
# Could not map gene symbol:mrda_haein peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:mrda_haein peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:mrda_haein peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:mrda_haein peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:mrda_haein peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:mrda_haein peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:mrda_haein peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:vph1
# Could not map gene symbol:q96885_9hepc rna dependent rna polymerase (fragment) (trembl)
# Could not map gene symbol:q96885_9hepc rna dependent rna polymerase (fragment) (trembl)
# Could not map gene symbol:parc_staau dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_staa3 dna gyrase subunit a (sprot)
# Could not map gene symbol:nram_i83a1 neuraminidase (sprot)
# Could not map gene symbol:q7zjm1_9hiv1 integrase (fragment) (trembl)
# Could not map gene symbol:a9uf02_human non-specific protein-tyrosine kinase (trembl)
# Could not map gene symbol:mura_ecoli udp-n-acetylglucosamine 1-carboxyvinyltransferase (sprot)
# Could not map gene symbol:q5l478_9hepc nonstructural protein 5a (fragment) (trembl)
# Could not map gene symbol:q5l478_9hepc nonstructural protein 5a (fragment) (trembl)
# Could not map gene symbol:q68hc5_ajeca lanosterol 14-alpha-demethylase (trembl)
# Could not map gene symbol:erg11
# Could not map gene symbol:cp51a_aspfn sterol 14-alpha demethylase (sprot)
# Could not map gene symbol:fgsg_11024
# Could not map gene symbol:erg11
# Could not map gene symbol:cp51a_aspfn sterol 14-alpha demethylase (sprot)
# Could not map gene symbol:tbb_triru tubulin beta chain (sprot)
# Could not map gene symbol:tbb_triru tubulin beta chain (sprot)
# Could not map gene symbol:tbb_triru tubulin beta chain (sprot)
# Could not map gene symbol:f1l348_ascsu acetylcholine receptor subunit alpha-type unc-38 (trembl)
# Could not map gene symbol:f1kyn0_ascsu acetylcholine receptor subunit beta-type unc-29 (trembl)
# Could not map gene symbol:cp51a_aspfn sterol 14-alpha demethylase (sprot)
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:q9hgt2_canax leucine--trna ligase (trembl)
# Could not map gene symbol:pf3d7_1446800
# Could not map gene symbol:calm1_human calmodulin-1 (sprot)
# Could not map gene symbol:ul30
# Could not map gene symbol:dpol_hcmva dna polymerase catalytic subunit (sprot)
# Could not map gene symbol:lyta
# Could not map gene symbol:lyta
# Could not map gene symbol:lyta
# Could not map gene symbol:atl_staau bifunctional autolysin (sprot)
# Could not map gene symbol:pbp2_strr6 penicillin-binding protein 2b (sprot)
# Could not map gene symbol:pbpa_strr6 penicillin-binding protein 1a (sprot)
# Could not map gene symbol:pbp2_strr6 penicillin-binding protein 2b (sprot)
# Could not map gene symbol:pbpa_strr6 penicillin-binding protein 1a (sprot)
# Could not map gene symbol:bla2_ecolx beta-lactamase shv-2 (sprot)
# Could not map gene symbol:bla1_ecolx beta-lactamase shv-1 (sprot)
# Could not map gene symbol:que80_rs28345
# Could not map gene symbol:bla1_klepn beta-lactamase shv-1 (sprot)
# Could not map gene symbol:blkpc_klepn carbapenem-hydrolyzing beta-lactamase kpc (sprot)
# Could not map gene symbol:ampc_entcl beta-lactamase (sprot)
# Could not map gene symbol:j7649_rs14730
# Could not map gene symbol:bla2_ecolx beta-lactamase shv-2 (sprot)
# Could not map gene symbol:bla1_ecolx beta-lactamase shv-1 (sprot)
# Could not map gene symbol:que80_rs28345
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:exp1_plafa malaria protein exp-1 (sprot)
# Could not map gene symbol:q5l478_9hepc nonstructural protein 5a (fragment) (trembl)
# Could not map gene symbol:q7zjm1_9hiv1 integrase (fragment) (trembl)
# Could not map gene symbol:parc_mycpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_mycpn dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_strr6 dna gyrase subunit a (sprot)
# Could not map gene symbol:cpb_rs03685
# Could not map gene symbol:gyra
# Could not map gene symbol:parc_haein dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_haein dna gyrase subunit a (sprot)
# Could not map gene symbol:q54906_strpy penicillin-binding protein (trembl)
# Could not map gene symbol:mrda_ecoli peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:mrda_ecoli peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:saouhsc_01145
# Could not map gene symbol:pbp2_strr6 penicillin-binding protein 2b (sprot)
# Could not map gene symbol:rpob
# Could not map gene symbol:embc
# Could not map gene symbol:embb
# Could not map gene symbol:emba
# Could not map gene symbol:cyb_plafa cytochrome b (sprot)
# Could not map gene symbol:pf3d7_0603300
# Could not map gene symbol:e2
# Could not map gene symbol:gl50803_0017063
# Could not map gene symbol:pno_crypv pyruvate dehydrogenase [nadp(+)] (sprot)
# Could not map gene symbol:u5ehr3_nocas dihydropteroate synthase (trembl)
# Could not map gene symbol:q8gnd6_shiso dihydropteroate synthase (fragment) (trembl)
# Could not map gene symbol:o44030_toxgo dihydropteroate synthase (trembl)
# Could not map gene symbol:folp
# Could not map gene symbol:ddla
# Could not map gene symbol:alr
# Could not map gene symbol:drts_plafk bifunctional dihydrofolate reductase-thymidylate synthase (sprot)
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:q72547_9hiv1 reverse transcriptase/rnaseh (fragment) (trembl)
# Could not map gene symbol:q72874_9hiv1 pol polyprotein (fragment) (trembl)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:pare_strpn dna topoisomerase 4 subunit b (sprot)
# Could not map gene symbol:gyra_strpn dna gyrase subunit a (sprot)
# Could not map gene symbol:gyrb_strpn dna gyrase subunit b (sprot)
# Could not map gene symbol:gyra
# Could not map gene symbol:gyrb
# Could not map gene symbol:saouhsc_01352
# Could not map gene symbol:saouhsc_01351
# Could not map gene symbol:gyra_staa3 dna gyrase subunit a (sprot)
# Could not map gene symbol:gyrb_staam dna gyrase subunit b (sprot)
# Could not map gene symbol:saouhsc_01352
# Could not map gene symbol:saouhsc_01351
# Could not map gene symbol:gyra_staa3 dna gyrase subunit a (sprot)
# Could not map gene symbol:gyrb_staam dna gyrase subunit b (sprot)
# Could not map gene symbol:parc_mycpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:pare_mycpn dna topoisomerase 4 subunit b (sprot)
# Could not map gene symbol:gyra_mycpn dna gyrase subunit a (sprot)
# Could not map gene symbol:gyrb
# Could not map gene symbol:mrda_ecoli peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:mrda_ecoli peptidoglycan d,d-transpeptidase mrda (sprot)
# Could not map gene symbol:q72547_9hiv1 reverse transcriptase/rnaseh (fragment) (trembl)
# Could not map gene symbol:q9njg8_leido dna topoisomerase i (trembl)
# Could not map gene symbol:inha_myctu enoyl-[acyl-carrier-protein] reductase [nadh] (sprot)
# Could not map gene symbol:erg11
# Could not map gene symbol:q72547_9hiv1 reverse transcriptase/rnaseh (fragment) (trembl)
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:rl10_shifl large ribosomal subunit protein ul10 (sprot)
# Could not map gene symbol:rl10_shifl large ribosomal subunit protein ul10 (sprot)
# Could not map gene symbol:rl10_shifl large ribosomal subunit protein ul10 (sprot)
# Could not map gene symbol:nram_i75a5 neuraminidase (sprot)
# Could not map gene symbol:rs12_neig1 small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:pbpa_neigo penicillin-binding protein 1a (sprot)
# Could not map gene symbol:pbpa_strpn penicillin-binding protein 1a (sprot)
# Could not map gene symbol:q18bx5_clod6 rna polymerase sigma factor siga (trembl)
# Could not map gene symbol:q18bx5_clod6 rna polymerase sigma factor siga (trembl)
# Could not map gene symbol:q72874_9hiv1 pol polyprotein (fragment) (trembl)
# Could not map gene symbol:q72874_9hiv1 pol polyprotein (fragment) (trembl)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_strpn dna gyrase subunit a (sprot)
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:parc_haein dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_haein dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_ecoli dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:atpl_myctu atp synthase subunit c (sprot)
# Could not map gene symbol:atpl_myctu atp synthase subunit c (sprot)
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:dpol_vzvd dna polymerase catalytic subunit (sprot)
# Could not map gene symbol:dpol_vzvd dna polymerase catalytic subunit (sprot)
# Could not map gene symbol:p87764_9hepc nonstructural protein 5b (fragment) (trembl)
# Could not map gene symbol:inha_myctu enoyl-[acyl-carrier-protein] reductase [nadh] (sprot)
# Could not map gene symbol:polg_hcv77 genome polyprotein (sprot)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_strr6 dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_strr6 dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_mycpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_mycpn dna gyrase subunit a (sprot)
# Could not map gene symbol:a0a0c4mi94_klepn dna topoisomerase 4 subunit a (trembl)
# Could not map gene symbol:gyra
# Could not map gene symbol:q72547_9hiv1 reverse transcriptase/rnaseh (fragment) (trembl)
# Could not map gene symbol:q53i07_9hiv1 env polyprotein (fragment) (trembl)
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:parc_staau dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_staa3 dna gyrase subunit a (sprot)
# Could not map gene symbol:erg1
# Could not map gene symbol:rplp
# Could not map gene symbol:q72874_9hiv1 pol polyprotein (fragment) (trembl)
# Could not map gene symbol:q5l478_9hepc nonstructural protein 5a (fragment) (trembl)
# Could not map gene symbol:dpol_hbvf1 protein p (sprot)
# Could not map gene symbol:o39930_9hepc rna-directed rna polymerase (fragment) (trembl)
# Could not map gene symbol:q72547_9hiv1 reverse transcriptase/rnaseh (fragment) (trembl)
# Could not map gene symbol:q5l478_9hepc nonstructural protein 5a (fragment) (trembl)
# Could not map gene symbol:rpob_ecoli dna-directed rna polymerase subunit beta (sprot)
# Could not map gene symbol:bllf1
# Could not map gene symbol:b0b3c9_9hepc genome polyprotein (fragment) (trembl)
# Could not map gene symbol:q72547_9hiv1 reverse transcriptase/rnaseh (fragment) (trembl)
# Could not map gene symbol:erg11
# Could not map gene symbol:rpoc
# Could not map gene symbol:na
# Could not map gene symbol:j5e45_rs14170
# Could not map gene symbol:q72874_9hiv1 pol polyprotein (fragment) (trembl)
# Could not map gene symbol:b0b3c9_9hepc genome polyprotein (fragment) (trembl)
# Could not map gene symbol:q72874_9hiv1 pol polyprotein (fragment) (trembl)
# Could not map gene symbol:q5l478_9hepc nonstructural protein 5a (fragment) (trembl)
# Could not map gene symbol:pbpa_strr6 penicillin-binding protein 1a (sprot)
# Could not map gene symbol:pbpa_strr6 penicillin-binding protein 1a (sprot)
# Could not map gene symbol:erg11
# Could not map gene symbol:b0b3c9_9hepc genome polyprotein (fragment) (trembl)
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:q72547_9hiv1 reverse transcriptase/rnaseh (fragment) (trembl)
# Could not map gene symbol:q72874_9hiv1 pol polyprotein (fragment) (trembl)
# Could not map gene symbol:q91rs4_9hepc ns3 protease (fragment) (trembl)
# Could not map gene symbol:pbp2a_strr6 penicillin-binding protein 2a (sprot)
# Could not map gene symbol:pbp2a_strr6 penicillin-binding protein 2a (sprot)
# Could not map gene symbol:pbp2a_strr6 penicillin-binding protein 2a (sprot)
# Could not map gene symbol:pbp2a_strr6 penicillin-binding protein 2a (sprot)
# Could not map gene symbol:rs12_ecoli small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:rpsl
# Could not map gene symbol:rs12_ecoli small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:rs12_staa8 small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:rs12_ecoli small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:rs12_ecoli small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:rs12_ecoli small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:rs12_ecoli small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:rs12_staa8 small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:rs12_ecoli small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:rs12_staa8 small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:rs12_klep3 small ribosomal subunit protein us12 (sprot)
# Could not map gene symbol:q155p6_serma small ribosomal subunit protein us12 (trembl)
# Could not map gene symbol:saouhsc_00006
# Could not map gene symbol:saouhsc_01352
# Could not map gene symbol:gyra
# Could not map gene symbol:topa
# Could not map gene symbol:gyra_strpn dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_ecoli dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_ecoli dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:a6tbt6_klep7 dna gyrase subunit a (trembl)
# Could not map gene symbol:a6te12_klep7 dna topoisomerase 4 subunit a (trembl)
# Could not map gene symbol:gyra
# Could not map gene symbol:parc
# Could not map gene symbol:gyra_strpn dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_mycpn dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_mycpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_strpn dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:saouhsc_00006
# Could not map gene symbol:saouhsc_01352
# Could not map gene symbol:a6tbt6_klep7 dna gyrase subunit a (trembl)
# Could not map gene symbol:a6te12_klep7 dna topoisomerase 4 subunit a (trembl)
# Could not map gene symbol:saouhsc_00006
# Could not map gene symbol:saouhsc_01352
# Could not map gene symbol:gyra_strp1 dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_strp1 dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_ecoli dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_mycpn dna gyrase subunit a (sprot)
# Could not map gene symbol:top1_mycpn dna topoisomerase 1 (sprot)
# Could not map gene symbol:q7vkw4_haedu dna gyrase subunit a (trembl)
# Could not map gene symbol:q7vl92_haedu dna topoisomerase 4 subunit a (trembl)
# Could not map gene symbol:gyra
# Could not map gene symbol:g4nn22_chlt4 dna topoisomerase 1 (trembl)
# Could not map gene symbol:saouhsc_00006
# Could not map gene symbol:saouhsc_01352
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_ecoli dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_shifl dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_shifl dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_shifl dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_shifl dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_1
# Could not map gene symbol:g4nn22_chlt4 dna topoisomerase 1 (trembl)
# Could not map gene symbol:a0a156ykx6_entcl dna gyrase subunit a (trembl)
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_ecoli dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_neigo dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_neigo dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:saouhsc_00006
# Could not map gene symbol:saouhsc_01352
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_ecoli dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:w1did1_klepn dna gyrase subunit a (trembl)
# Could not map gene symbol:w1dee8_klepn dna topoisomerase 4 subunit a (trembl)
# Could not map gene symbol:saouhsc_00006
# Could not map gene symbol:saouhsc_01352
# Could not map gene symbol:gyra_strpn dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_strpn dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_mycpn dna gyrase subunit a (sprot)
# Could not map gene symbol:top1_mycpn dna topoisomerase 1 (sprot)
# Could not map gene symbol:gyra_strpn dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_strpn dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:saouhsc_00006
# Could not map gene symbol:saouhsc_01352
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_ecoli dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_ecoli dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:saouhsc_00006
# Could not map gene symbol:saouhsc_01352
# Could not map gene symbol:gyra
# Could not map gene symbol:parc_strp3 dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:a0a717ur96_salti dna gyrase subunit a (trembl)
# Could not map gene symbol:a0a715kjc7_salti dna topoisomerase 4 subunit a (trembl)
# Could not map gene symbol:gyra_ecoli dna gyrase subunit a (sprot)
# Could not map gene symbol:parc_ecoli dna topoisomerase 4 subunit a (sprot)
# Could not map gene symbol:rpsd
# Could not map gene symbol:rs9_cutak small ribosomal subunit protein us9 (sprot)
# Could not map gene symbol:rpsd
# Could not map gene symbol:rpsi
# Could not map gene symbol:rpsd
# Could not map gene symbol:rs9_barqu small ribosomal subunit protein us9 (sprot)
# Could not map gene symbol:rpsd
# Could not map gene symbol:rs9_mycpn small ribosomal subunit protein us9 (sprot)
# Could not map gene symbol:rpsd
# Could not map gene symbol:rpsd
# Could not map gene symbol:rpsi
# Could not map gene symbol:rs4
# Could not map gene symbol:rs9
# Could not map gene symbol:rpsd
# Could not map gene symbol:rpsi
# Could not map gene symbol:rs4_lismf small ribosomal subunit protein us4 (sprot)
# Could not map gene symbol:rpsi
# Could not map gene symbol:rs4
# Could not map gene symbol:rs9
# Could not map gene symbol:rpsd
# Could not map gene symbol:rpsi
# Could not map gene symbol:rpsd
# Could not map gene symbol:rpsi
# Could not map gene symbol:rpsd
# Could not map gene symbol:rs9_strzp small ribosomal subunit protein us9 (sprot)
# Could not map gene symbol:rpsd
# Could not map gene symbol:rpsi
# Could not map gene symbol:rs4_bordl small ribosomal subunit protein us4 (sprot)
# Could not map gene symbol:rs9_bordl small ribosomal subunit protein us9 (sprot)
# Could not map gene symbol:rpsd
# Could not map gene symbol:rpsi
# Could not map gene symbol:rpsd
# Could not map gene symbol:rs9_strzp small ribosomal subunit protein us9 (sprot)
# Could not map gene symbol:rpsd
# Could not map gene symbol:rpsi
# Could not map gene symbol:rpsd
# Could not map gene symbol:rs9_trepa small ribosomal subunit protein us9 (sprot)
# Could not map gene symbol:rs4
# Could not map gene symbol:rs9
# Could not map gene symbol:rpsd
# Could not map gene symbol:q5nfg2_fratt small ribosomal subunit protein us9 (trembl)
# Could not map gene symbol:rs4_ecoli small ribosomal subunit protein us4 (sprot)
# Could not map gene symbol:rs9_ecoli small ribosomal subunit protein us9 (sprot)
# Could not map gene symbol:rpsd
# Could not map gene symbol:rs9_trepa small ribosomal subunit protein us9 (sprot)
# Could not map gene symbol:efg_staau elongation factor g (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:efg_barqu elongation factor g (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:fusa
# Could not map gene symbol:fusa
# Could not map gene symbol:efg_haedu elongation factor g (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:efg1_vibch elongation factor g 1 (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:efg_staau elongation factor g (sprot)
# Could not map gene symbol:efg_ecoli elongation factor g (sprot)
# Could not map gene symbol:efg_staau elongation factor g (sprot)
# Could not map gene symbol:efg_staau elongation factor g (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:fusa
# Could not map gene symbol:efg_staau elongation factor g (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:fusa
# Could not map gene symbol:fusa
# Could not map gene symbol:efg_ecoli elongation factor g (sprot)
# Could not map gene symbol:efg_staau elongation factor g (sprot)
# Could not map gene symbol:efg_strpg elongation factor g (sprot)
# Could not map gene symbol:efg_strps elongation factor g (sprot)
# Could not map gene symbol:efg_strps elongation factor g (sprot)
# Could not map gene symbol:efg_strps elongation factor g (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:efg_staau elongation factor g (sprot)
# Could not map gene symbol:efg_coxb1 elongation factor g (sprot)
# Could not map gene symbol:b5rpn9_borra elongation factor g (trembl)
# Could not map gene symbol:efg_ricri elongation factor g (sprot)
# Could not map gene symbol:efg_ricri elongation factor g (sprot)
# Could not map gene symbol:efg_oriti elongation factor g (sprot)
# Could not map gene symbol:efg_strps elongation factor g (sprot)
# Could not map gene symbol:efg_ricri elongation factor g (sprot)
# Could not map gene symbol:efg_staau elongation factor g (sprot)
# Could not map gene symbol:efg_strpg elongation factor g (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:fusa
# Could not map gene symbol:efg_frat1 elongation factor g (sprot)
# Could not map gene symbol:efg_ricty elongation factor g (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:efg_ecoli elongation factor g (sprot)
# Could not map gene symbol:fusa
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11
# Could not map gene symbol:gag-pol
# Could not map gene symbol:gag-pol
# Could not map gene symbol:gag-pol
# Could not map gene symbol:gag-pol
# Could not map gene symbol:gag-pol
# Could not map gene symbol:gag-pol
# Could not map gene symbol:gag-pol
# Could not map gene symbol:gag-pol
# Could not map gene symbol:gag-pol
# Could not map gene symbol:gag-pol
# Could not map gene symbol:nd4
# Could not map gene symbol:nd4l
# Could not map gene symbol:nd2
# Could not map gene symbol:nd3
# Could not map gene symbol:nd6
# Could not map gene symbol:nd1
# Could not map gene symbol:nd5
# Could not map gene symbol:e2
# Could not map gene symbol:na
# Could not map gene symbol:erg11
# Could not map gene symbol:erg11

# %%
mask = stacked_df['gene_name'] != 'null' ###remove all rows where gene couldnt be converted to protein name
filtered_df = stacked_df[mask]
filtered_df.rename(columns ={'gene_name':'protein_name'},inplace = True) ####we only select drug, disease, and protein columns for final dataframe
final_columns = ['drug_name','disease_name','protein_name']
final_df = filtered_df.drop_duplicates(subset = final_columns)
final_df = final_df.reset_index().drop('index', axis = 1).drop('gene_id',axis=1).drop('drug_id',axis=1).drop('disease_id',axis=1)

final_df.to_csv(os.path.join(parent_dir,'ROBOKOP+DrugmechDB Data/ROBOMechDB Processed Triples.csv'))
# Out:
# /var/folders/91/rbzkmg7n5g7f992d83ryjnz40000gn/T/ipykernel_75130/706145218.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.rename(columns ={'gene_name':'protein_name'},inplace = True) ####we only select drug, disease, and protein columns for final dataframe

# %%
final_df.to_csv('/Users/eding/Desktop/U24 ROBOKOP Project/Step 1 Data Processing/ROBOKOP+DrugmechDB/ROBOKOP+DrugmechDB Data/ROBOMechDB Processed Triples.csv')
